# %%
import pandas as pd
df_bm = pd.read_csv('Datasets/body-measurements.csv')
df_bm
# Out:
#      Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth   Belly   \
# 0       1.0   30                 22             18           20      18
# 1       1.0   28                 19             22           17      18
# 2       2.0   27                 21             18           16      14
# 3       1.0   29                 20             20           18      11
# 4       2.0   28                 16             14           18      13
# ..      ...  ...                ...            ...          ...     ...
# 711     2.0   13                 22              6           14      25
# 712     1.0   10                 21             11           12      22
# 713     1.0    4                 20             17           11      22
# 714     1.0   13                 20             15           14      25
# 715     2.0    4                 20             15           10      20
#
#      Waist   Hips   ArmLength   ShoulderToWaist   WaistToKnee   LegLength  \
# ...

# %%
import pandas as pd
df_bmi = pd.read_csv('Datasets/dataset-bmi.csv')
df_bmi
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
import pandas as pd
df1 = pd.read_csv('Datasets/dataset1.csv')
df1
# Out:
#                   Date Workout Name Duration             Exercise Name  \
# 0     13/09/2021 10:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 1     13/09/2021 10:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2     13/09/2021 10:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 3     13/09/2021 10:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 4     13/09/2021 10:41       PUSH 1   1h 12m   Incline Cable Chest Fly
# ...                ...          ...      ...                       ...
# 3984  02/02/2024 17:37      PULL 2       30m  Lateral Raise (Dumbbell)
# 3985  02/02/2024 17:37      PULL 2       30m        Seated Row (Cable)
# 3986  02/02/2024 17:37      PULL 2       30m        Seated Row (Cable)
# 3987  02/02/2024 17:37      PULL 2       30m        Seated Row (Cable)
# 3988  02/02/2024 17:37      PULL 2       30m        Seated Row (Cable)
#
#       Set Order  Weight  Reps  Distance  Seconds Notes  \
# 0             1   35.00    10         0        0   NaN
# ...

# %%
import pandas as pd
df2 = pd.read_csv('Datasets/dataset2.csv')
df2
# Out:
#                   Date        Workout Name                  Exercise Name  \
# 0     23/10/2015 17:06               Chest  Incline Bench Press (Barbell)
# 1     23/10/2015 17:06               Chest  Incline Bench Press (Barbell)
# 2     23/10/2015 17:06               Chest  Incline Bench Press (Barbell)
# 3     23/10/2015 17:06               Chest  Incline Bench Press (Barbell)
# 4     23/10/2015 17:06               Chest  Incline Bench Press (Barbell)
# ...                ...                 ...                            ...
# 9927  29/09/2018 14:35  Push - Incline #40     Low Incline Dumbbell Bench
# 9928  29/09/2018 14:35  Push - Incline #40     Low Incline Dumbbell Bench
# 9929  29/09/2018 14:35  Push - Incline #40      Lateral Raise (Dumbbells)
# 9930  29/09/2018 14:35  Push - Incline #40      Lateral Raise (Dumbbells)
# 9931  29/09/2018 14:35  Push - Incline #40      Lateral Raise (Dumbbells)
#
#       Set Order  Weight  Reps  Distance  Seconds Notes Workout Notes
# ...

# %%
import pandas as pd
df3 = pd.read_csv('Datasets/dataset3.csv')
df3
# Out:
#       Unnamed: 0                                           Title  \
# 0              0                          Partner plank band row
# 1              1                    Banded crunch isometric hold
# 2              2                           FYR Banded Plank Jack
# 3              3                                   Banded crunch
# 4              4                                          Crunch
# ...          ...                                             ...
# 2913        2913                            EZ-bar skullcrusher-
# 2914        2914  Lying Close-Grip Barbell Triceps Press To Chin
# 2915        2915          EZ-Bar Skullcrusher - Gethin Variation
# 2916        2916                                TBS Skullcrusher
# 2917        2917                     30 Arms EZ-Bar Skullcrusher
#
#                                                    Desc      Type    BodyPart  \
# 0     The partner plank band row is an abdominal exe...  Strength  Abdominals
# ...

# %%
import pandas as pd
df4 = pd.read_csv("Datasets/archive/final_dataset_BFP.csv")
df4
# Out:
#           Weight    Height        BMI  Body Fat Percentage     BFPcase  \
# 0      76.811975  1.820521  23.175956            18.281148  Acceptable
# 1      77.721154  1.945498  20.534184            13.731021     Fitness
# 2      87.558726  1.742754  28.828859            42.304631       Obese
# 3      89.473356  1.758318  28.940017            27.958021       Obese
# 4      69.963943  1.722570  23.578732            16.464478     Fitness
# ...          ...       ...        ...                  ...         ...
# 4995   87.003054  1.902891  24.027404            16.772884     Fitness
# 4996   92.121555  1.779346  29.096464            30.215757       Obese
# 4997  105.298845  1.972883  27.053345            31.214014       Obese
# 4998   90.411999  1.803409  27.799528            29.579434       Obese
# 4999   54.641104  1.402966  27.760382            42.862459       Obese
#
#       Gender  Age      BMIcase  Exercise Recommendation Plan
# ...

# %%
import pandas as pd
df5 = pd.read_csv("Datasets/archive/final_dataset.csv")
df5
# Out:
#           Weight    Height        BMI  Gender  Age         BMIcase  \
# 0      92.085190  1.760250  29.719488  Female   59     over weight
# 1      61.089124  1.595499  23.997776  Female   25          normal
# 2      82.454037  1.816538  24.987499  Female   50          normal
# 3     101.713306  1.790696  31.720047  Female   62           obese
# 4      99.609527  1.969726  25.673756    Male   57     over weight
# ...          ...       ...        ...     ...  ...             ...
# 4995   55.256111  1.442648  26.549697  Female   23     over weight
# 4996  106.683815  1.779544  33.688435  Female   65    severe obese
# 4997   55.645396  1.915978  15.158221    Male   26  sever thinness
# 4998   83.748623  1.751525  27.298892  Female   55     over weight
# 4999  103.344782  1.789984  32.254493  Female   22    severe obese
#
#       Exercise Recommendation Plan
# 0                                5
# 1                                4
# 2                                4
# ...

# %%
import pandas as pd
df6 = pd.read_csv("Datasets/archive(2)/megaGymDataset.csv")
df6
# Out:
#       Unnamed: 0                                           Title  \
# 0              0                          Partner plank band row
# 1              1                    Banded crunch isometric hold
# 2              2                           FYR Banded Plank Jack
# 3              3                                   Banded crunch
# 4              4                                          Crunch
# ...          ...                                             ...
# 2913        2913                            EZ-bar skullcrusher-
# 2914        2914  Lying Close-Grip Barbell Triceps Press To Chin
# 2915        2915          EZ-Bar Skullcrusher - Gethin Variation
# 2916        2916                                TBS Skullcrusher
# 2917        2917                     30 Arms EZ-Bar Skullcrusher
#
#                                                    Desc      Type    BodyPart  \
# 0     The partner plank band row is an abdominal exe...  Strength  Abdominals
# ...

# %%
import pandas as pd
df7 = pd.read_excel('Datasets/gym recommendation/gym recommendation.xlsx')
df7
# Out:
#           ID   Sex  Age  Height  Weight Hypertension Diabetes    BMI  \
# 0          1  Male   18    1.68    47.5           No       No  16.83
# 1          2  Male   18    1.68    47.5          Yes       No  16.83
# 2          3  Male   18    1.68    47.5           No      Yes  16.83
# 3          4  Male   18    1.68    47.5          Yes      Yes  16.83
# 4          5  Male   18    1.68    47.5           No       No  16.83
# ...      ...   ...  ...     ...     ...          ...      ...    ...
# 14584  14585  Male   35    1.88    98.0           No       No  27.73
# 14585  14586  Male   36    1.89    99.0           No       No  27.71
# 14586  14587  Male   37    1.90   100.0           No       No  27.70
# 14587  14588  Male   38    1.91   101.0           No       No  27.69
# 14588  14589  Male   39    1.92   102.0           No       No  27.67
#
#              Level Fitness Goal      Fitness Type  \
# 0      Underweight  Weight Gain  Muscular Fitness
# ...
