# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import joblib

# %%
# Load and prepare your datasets
profile_data = pd.read_csv('Datasets/archive/final_dataset.csv')
workout_data = pd.read_csv('Datasets/archive(2)/megaGymDataset.csv')

# %%
profile_data.head()
# Out:
#        Weight    Height        BMI  Gender  Age      BMIcase  \
# 0   92.085190  1.760250  29.719488  Female   59  over weight
# 1   61.089124  1.595499  23.997776  Female   25       normal
# 2   82.454037  1.816538  24.987499  Female   50       normal
# 3  101.713306  1.790696  31.720047  Female   62        obese
# 4   99.609527  1.969726  25.673756    Male   57  over weight
#
#    Exercise Recommendation Plan
# 0                             5
# 1                             4
# 2                             4
# 3                             6
# 4                             5

# %%
workout_data.head()
# Out:
#    Unnamed: 0                         Title  \
# 0           0        Partner plank band row
# 1           1  Banded crunch isometric hold
# 2           2         FYR Banded Plank Jack
# 3           3                 Banded crunch
# 4           4                        Crunch
#
#                                                 Desc      Type    BodyPart  \
# 0  The partner plank band row is an abdominal exe...  Strength  Abdominals
# 1  The banded crunch isometric hold is an exercis...  Strength  Abdominals
# 2  The banded plank jack is a variation on the pl...  Strength  Abdominals
# 3  The banded crunch is an exercise targeting the...  Strength  Abdominals
# 4  The crunch is a popular core exercise targetin...  Strength  Abdominals
#
#   Equipment         Level  Rating RatingDesc
# 0     Bands  Intermediate     0.0        NaN
# 1     Bands  Intermediate     NaN        NaN
# 2     Bands  Intermediate     NaN        NaN
# 3     Bands  Intermediate     NaN        NaN
# ...

# %%
# print(profile_data.to_string)
# print(profile_data)

# print(pd.options.display.max_rows)
# pd.options.display.max_rows = 9999

# print(workout_data.to_string)
# print(workoute_data)

# print(pd.options.display.max_rows)
# pd.options.display.max_rows = 9999

# %%
# Preprocess data (handle missing values, encoding, etc.)
# Example: Encode categorical features
label_encoders = {}
for column in ['Gender', 'BMIcase']:
    le = LabelEncoder()
    profile_data[column] = le.fit_transform(profile_data[column])
    label_encoders[column] = le

# %%
# Define the columns to drop
columns_to_drop = ['Gender', 'Age', 'BMIcase']

# %%
# Drop columns that exist in the DataFrame
columns_to_drop_existing = [col for col in columns_to_drop if col in profile_data.columns]
profile_data = profile_data.drop(columns=columns_to_drop_existing)

# %%
# columns_to_drop2 = ['Unnamed: 0', 'Rating', 'RatingDesc']

# %%
# Drop columns that exist in the DataFrame
# columns_to_drop2_existing = [col for col in columns_to_drop2 if col in workout_data.columns]
# workout_data = workout_data.drop(columns=columns_to_drop2_existing)

# %%
print(profile_data.head())
# Out:
#        Weight    Height        BMI  Exercise Recommendation Plan
# 0   92.085190  1.760250  29.719488                             5
# 1   61.089124  1.595499  23.997776                             4
# 2   82.454037  1.816538  24.987499                             4
# 3  101.713306  1.790696  31.720047                             6
# 4   99.609527  1.969726  25.673756                             5

# %%
print(workout_data.head())
# Out:
#                           Title  \
# 0        Partner plank band row
# 1  Banded crunch isometric hold
# 2         FYR Banded Plank Jack
# 3                 Banded crunch
# 4                        Crunch
#
#                                                 Desc      Type    BodyPart  \
# 0  The partner plank band row is an abdominal exe...  Strength  Abdominals
# 1  The banded crunch isometric hold is an exercis...  Strength  Abdominals
# 2  The banded plank jack is a variation on the pl...  Strength  Abdominals
# 3  The banded crunch is an exercise targeting the...  Strength  Abdominals
# 4  The crunch is a popular core exercise targetin...  Strength  Abdominals
#
#   Equipment         Level
# 0     Bands  Intermediate
# 1     Bands  Intermediate
# 2     Bands  Intermediate
# 3     Bands  Intermediate
# 4     Bands  Intermediate

# %%
# Get unique values in the BMIcase column
# unique_bmi_cases = profile_data['BMIcase'].unique()
# print(unique_bmi_cases)

# %%
# Define features and target
X = profile_data.drop('Exercise Recommendation Plan', axis=1)
y = profile_data['Exercise Recommendation Plan']

# %%
# Define features and target, including 'Age', 'BMI', and 'BMIcase'
# features = ['Weight', 'Height', 'BMI', 'Gender', 'Age', 'BMIcase']
# X = profile_data[features]
# y = profile_data['Exercise Recommendation Plan']

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Evaluate the model
# predictions = model.predict(X_test)
# accuracy = accuracy_score(y_test, predictions)
# accuracy

# %%
# Evaluate the model
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f'Model Accuracy: {accuracy}')
# Out:
# Model Accuracy: 0.813

# %%
from joblib import dump

# %%
dump(model, './../Saved_Models/model4.joblib')
# Out:
# ['./../Saved_Models/model4.joblib']
